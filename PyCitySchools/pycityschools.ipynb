# %%
# Dependencies and Setup
import pandas as pd

# %%
# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# %%
# Read School and Student Data File and store into Pandas DataFrames
school_data_df = pd.read_csv(school_data_to_load)
student_data_df = pd.read_csv(student_data_to_load)

# %%
# Read School and Student Data File and store into Pandas DataFrames
school_data_df = pd.read_csv(school_data_to_load)
student_data_df = pd.read_csv(student_data_to_load)

# %%
# Print the data to the screen
school_data_df.head()

# %%
student_data_df.head()

# %%
school_data_df.columns

# %%
school_data_df.count()

# %%
student_data_df.columns

# %%
student_data_df.count()

# %%
#Create District Summary
#Calculate the total number of schools

school_count = school_data_df["School ID"].count()

#Calculate the total number of students

student_count = student_data_df["Student ID"].count()

#Calculate the total budget

total_budget_count = school_data_df["budget"].sum()

#Calculate the average math score

avg_math_score_count = student_data_df["math_score"].mean()

#Calculate the average reading score

avg_reading_score_count = student_data_df["reading_score"].mean()

#Calculate the percentage of students with a passing math score (70 or greater)
 
passing_math_percentage = student_data_df(["math_score"]/["math_score"].sum()) * 100

#Calculate the percentage of students with a passing reading score (70 or greater)

passing_reading_percentage = student_data_df(["reading_score"]/["reading_score"].sum()) * 100

#Calculate the percentage of students who passed math and reading (% Overall Passing)

passing_combined_percentage =

print(student_count,student_count,total_budget_count,avg_math_score_count,avg_reading_score_count,passing_math_percentage,passing_reading_percentage)

# %%
# Place all of the data found into a summary DataFrame
District_Summary_df = pd.DataFrame({"Total Schools": [school_count], "Total Students": student_count,
                              "Total Budget": total_budget_count, "Average Math Score": avg_math_score_count,
                              "Average Reading Score": avg_reading_score_count , "% Passing Math": passing_math_percentage,
                              "% Passing Reading": passing_reading_percentage, "% Overall Passing"})

# %%
# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
